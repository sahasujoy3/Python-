# %% [markdown]
# <a href="https://colab.research.google.com/github/sahasujoy3/Python-/blob/main/Python_Workshop_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
myname="Sujoy"
my_dep="BS"
_my_University="SRU"
myLoc="Warangal"
MYLOC="Telangana"
mydep2="BS"

print(myname)
print(my_dep)
print(myLoc)
print(MYLOC)
print(mydep2)
# Out:
# Sujoy
# BS
# Warangal
# Telangana
# BS

# %%
a=input("Enter the value of a")
b=input("Enter the value of b")
print("=================")
print("Simple Calculator")
print("=================")
print("Addition=",a+b)
print("=================")
# Out:
# Enter the value of a10
# Enter the value of b10
# =================
# Simple Calculator
# =================
# Addition= 1010
# =================

# %%
a=input("Enter the value of a")
b=input("Enter the value of b")
a=int(a)
b=int(b)
print("=================")
print("Simple Calculator")
print("=================")
print("Addition=",a+b)
print("Multiplication",a*b)
print("Subtraction",a-b)
print("Division",a/b)
print("Reminder",a%b)
print("=================")
# Out:
# Enter the value of a10
# Enter the value of b5
# =================
# Simple Calculator
# =================
# Addition= 15
# Multiplication 50
# Subtraction 5
# Division 2.0
# Reminder 0
# =================

# %%
print (a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_598/2097511479.py in <cell line: 0>()
# ----> 1 print (a)
#
# NameError: name 'a' is not defined
