# %% [markdown]
# <a href="https://colab.research.google.com/github/sahasujoy3/Python-/blob/main/Pyhon_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Day 1***

# %%
import keyword
print ("Number of keywords=",len(keyword.kwlist))
print ("soft keyword=",keyword.softkwlist)
print ("all keyword=",keyword.kwlist)
# Out:
# Number of keywords= 35
# soft keyword= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Print Statement

# %%
import keyword
print("No of keywords=", len(keyword.kwlist))
# Out:
# No of keywords= 35

# %% [markdown]
# Variables

# %%
x=5
y="John"
z=3.0

print(x)
print(y)
print(z)
# Out:
# 5
# John
# 3.0

# %%
x=5
y="John"
z=3.0

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(x) print(type(x))
# Out:
#   File "/tmp/ipykernel_1806/2579856218.py", line 1
#     print(x) print(type(x))
#              ^
# SyntaxError: invalid syntax

# %%
print (x)
print (type(x))
# Out:
# 5
# <class 'int'>

# %%
y1=2
print(y1)
print(type(y1))
# Out:
# 2
# <class 'int'>

# %%
y1=2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
y1=2.0
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)

print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2.0
# 2.0
# 2
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %%
c=50
d=float(c)

print(c)
print(d)
# Out:
# 50
# 50.0

# %%
a=2.3
A="Sujoy"
print(a)
print(A)
# Out:
# 2.3
# Sujoy

# %%
a=2.3
A="Sujoy"
print(a,A)
# Out:
# 2.3 Sujoy
